# %%
import time
import torch
import torch.nn.functional as F
from torch import nn
from torch.utils.data import DataLoader
from torchvision import datasets, transforms

# %%
# hyper params
batch_size = 256
learning_rate = 1e-2
num_epochs = 100

# %%
# downlaod Fashion MNIST dataset
train_dataset = datasets.FashionMNIST(
    root='./datasets', train=True, transform=transforms.ToTensor(), download=True)
test_dataset = datasets.FashionMNIST(
    root='./datasets', train=False, transform=transforms.ToTensor())

# %%
# using dataset to build data loader
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

# %%
# check about data
len(train_dataset), len(train_loader)
# for one epoch, we train all the data once. In one epoch we use "for" to data loader to traverse all batchs.
# Here one epoch we train 60000 records, in one epoch we run 938 batchs, each batch contains 64 records(batch size)
# Out:
# (60000, 235)

# %%
# logistic regression model
class logistic_regression(nn.Module):
    def __init__(self, in_dim, n_class):
        super(logistic_regression, self).__init__()
        self.fc = nn.Linear(in_dim, n_class)

    def forward(self, x):
        out = self.fc(x)
        # out = torch.sigmoid(out)
        return out

# %%
if __name__ == "__main__":
    # init 
    model = logistic_regression(28 * 28, 10)
    use_gpu = torch.cuda.is_available()
    if use_gpu:
        model = model.cuda()
    criterion = nn.CrossEntropyLoss() # loss function
    optimizer = torch.optim.SGD(model.parameters(), lr=learning_rate)

    # training
    print("Begin training...")

    for epoch in range(num_epochs):
        print("*" * 10)
        print(f"epoch {epoch + 1}")
        since = time.time()
        running_loss = 0.
        running_acc = 0.

        model.train()
        for i, data in enumerate(train_loader):
            img, label = data
            img = img.view(img.size(0), -1)
            if use_gpu:
                img = img.cuda()
                label = label.cuda()

            # forward
            out = model(img)
            loss = criterion(out, label)
            running_loss += loss.item()
            _, pred = torch.max(out, 1)
            running_acc += (pred == label).float().sum()

            # backward
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            # log
            if (i+1) % 50 == 0:
                print(f"Finish [{i+1} / {len(train_loader)}] batch, accuracy = {(pred == label).float().mean()}")
        print(f"Finish [{epoch+1} / {num_epochs}], running loss = {running_loss}, accuracy = {running_acc / len(train_dataset)}")
# Out:
# Begin training...
# **********
# epoch 1
# Finish [50 / 235] batch, accuracy = 0.62109375
# Finish [100 / 235] batch, accuracy = 0.625
# Finish [150 / 235] batch, accuracy = 0.69921875
# Finish [200 / 235] batch, accuracy = 0.7109375
# Finish [1 / 100], running loss = 321.83249312639236, accuracy = 0.6301666498184204
# **********
# epoch 2
# Finish [50 / 235] batch, accuracy = 0.6796875
# Finish [100 / 235] batch, accuracy = 0.71875
# Finish [150 / 235] batch, accuracy = 0.703125
# Finish [200 / 235] batch, accuracy = 0.75
# Finish [2 / 100], running loss = 215.75921231508255, accuracy = 0.7149166464805603
# **********
# epoch 3
# Finish [50 / 235] batch, accuracy = 0.7578125
# Finish [100 / 235] batch, accuracy = 0.7734375
# Finish [150 / 235] batch, accuracy = 0.75
# Finish [200 / 235] batch, accuracy = 0.73828125
# Finish [3 / 100], running loss = 189.03332167863846, accuracy = 0.7481499910354614
# **********
# epoch 4
# Finish [50 / 235] batch, accuracy = 0.74609375
# Finish [100 / 235] batch, accuracy = 0.7421875
# Finish [150 / 235] batch, accuracy = 0.78515625
# Finish [200 / 235] batch, accuracy = 0.77734375
# Finish [4 / 100], running loss = 174.86863374710083, accuracy = 0.7667166590690613
# **********
# epoch 5
# Finish [50 / 235] batch, accuracy = 0.76171875
# Finish [100 / 235] batch, accuracy = 0.7734375
# Finish [150 / 235] batch, accuracy = 0.80078125
# Finish [200 / 235] batch, accuracy = 0.7734375
# Finish [5 / 100], running loss = 165.4819217324257, accuracy = 0.7779499888420105
# **********
# epoch 6
# Finish [50 / 235] batch, accuracy = 0.74609375
# Finish [100 / 235] batch, accuracy = 0.80859375
# Finish [150 / 235] batch, accuracy = 0.77734375
# Finish [200 / 235] batch, accuracy = 0.77734375
# Finish [6 / 100], running loss = 158.76411938667297, accuracy = 0.7867333292961121
# **********
# epoch 7
# Finish [50 / 235] batch, accuracy = 0.8046875
# Finish [100 / 235] batch, accuracy = 0.87109375
# Finish [150 / 235] batch, accuracy = 0.7890625
# Finish [200 / 235] batch, accuracy = 0.796875
# Finish [7 / 100], running loss = 153.45456898212433, accuracy = 0.7937833070755005
# **********
# epoch 8
# Finish [50 / 235] batch, accuracy = 0.75
# Finish [100 / 235] batch, accuracy = 0.83203125
# Finish [150 / 235] batch, accuracy = 0.828125
# Finish [200 / 235] batch, accuracy = 0.83984375
# Finish [8 / 100], running loss = 149.18466186523438, accuracy = 0.79871666431427
# **********
# epoch 9
# Finish [50 / 235] batch, accuracy = 0.81640625
# Finish [100 / 235] batch, accuracy = 0.8125
# Finish [150 / 235] batch, accuracy = 0.83984375
# Finish [200 / 235] batch, accuracy = 0.78515625
# Finish [9 / 100], running loss = 145.75002586841583, accuracy = 0.8027333617210388
# **********
# epoch 10
# Finish [50 / 235] batch, accuracy = 0.81640625
# Finish [100 / 235] batch, accuracy = 0.7890625
# Finish [150 / 235] batch, accuracy = 0.84375
# Finish [200 / 235] batch, accuracy = 0.84765625
# Finish [10 / 100], running loss = 142.77867385745049, accuracy = 0.8064500093460083
# **********
# epoch 11
# Finish [50 / 235] batch, accuracy = 0.84765625
# Finish [100 / 235] batch, accuracy = 0.8359375
# Finish [150 / 235] batch, accuracy = 0.82421875
# Finish [200 / 235] batch, accuracy = 0.8203125
# Finish [11 / 100], running loss = 140.28897169232368, accuracy = 0.8083500266075134
# **********
# epoch 12
# Finish [50 / 235] batch, accuracy = 0.78125
# Finish [100 / 235] batch, accuracy = 0.765625
# Finish [150 / 235] batch, accuracy = 0.8046875
# Finish [200 / 235] batch, accuracy = 0.74609375
# Finish [12 / 100], running loss = 137.97604498267174, accuracy = 0.8117333054542542
# **********
# epoch 13
# Finish [50 / 235] batch, accuracy = 0.78515625
# Finish [100 / 235] batch, accuracy = 0.8125
# Finish [150 / 235] batch, accuracy = 0.83984375
# Finish [200 / 235] batch, accuracy = 0.8125
# Finish [13 / 100], running loss = 135.91784286499023, accuracy = 0.8133000135421753
# **********
# epoch 14
# Finish [50 / 235] batch, accuracy = 0.8125
# Finish [100 / 235] batch, accuracy = 0.8359375
# Finish [150 / 235] batch, accuracy = 0.82421875
# Finish [200 / 235] batch, accuracy = 0.85546875
# Finish [14 / 100], running loss = 134.2191191315651, accuracy = 0.8157833218574524
# **********
# epoch 15
# Finish [50 / 235] batch, accuracy = 0.79296875
# Finish [100 / 235] batch, accuracy = 0.7890625
# Finish [150 / 235] batch, accuracy = 0.8671875
# Finish [200 / 235] batch, accuracy = 0.83984375
# Finish [15 / 100], running loss = 132.45364034175873, accuracy = 0.8175833225250244
# **********
# epoch 16
# Finish [50 / 235] batch, accuracy = 0.80859375
# Finish [100 / 235] batch, accuracy = 0.78515625
# Finish [150 / 235] batch, accuracy = 0.84375
# Finish [200 / 235] batch, accuracy = 0.8203125
# Finish [16 / 100], running loss = 131.15334257483482, accuracy = 0.8200500011444092
# **********
# epoch 17
# Finish [50 / 235] batch, accuracy = 0.75390625
# Finish [100 / 235] batch, accuracy = 0.8515625
# Finish [150 / 235] batch, accuracy = 0.83203125
# Finish [200 / 235] batch, accuracy = 0.80859375
# Finish [17 / 100], running loss = 129.84075340628624, accuracy = 0.8217166662216187
# **********
# epoch 18
# Finish [50 / 235] batch, accuracy = 0.828125
# Finish [100 / 235] batch, accuracy = 0.8515625
# Finish [150 / 235] batch, accuracy = 0.796875
# Finish [200 / 235] batch, accuracy = 0.8359375
# Finish [18 / 100], running loss = 128.61082431674004, accuracy = 0.8227166533470154
# **********
# epoch 19
# Finish [50 / 235] batch, accuracy = 0.77734375
# Finish [100 / 235] batch, accuracy = 0.80859375
# Finish [150 / 235] batch, accuracy = 0.84375
# Finish [200 / 235] batch, accuracy = 0.8203125
# Finish [19 / 100], running loss = 127.42867249250412, accuracy = 0.8238499760627747
# **********
# epoch 20
# Finish [50 / 235] batch, accuracy = 0.8359375
# Finish [100 / 235] batch, accuracy = 0.8203125
# Finish [150 / 235] batch, accuracy = 0.83203125
# Finish [200 / 235] batch, accuracy = 0.828125
# Finish [20 / 100], running loss = 126.3965627849102, accuracy = 0.8248999714851379
# **********
# epoch 21
# Finish [50 / 235] batch, accuracy = 0.83984375
# Finish [100 / 235] batch, accuracy = 0.859375
# Finish [150 / 235] batch, accuracy = 0.75390625
# Finish [200 / 235] batch, accuracy = 0.8203125
# Finish [21 / 100], running loss = 125.44924053549767, accuracy = 0.8259833455085754
# **********
# epoch 22
# Finish [50 / 235] batch, accuracy = 0.8125
# Finish [100 / 235] batch, accuracy = 0.83203125
# Finish [150 / 235] batch, accuracy = 0.84375
# Finish [200 / 235] batch, accuracy = 0.83203125
# Finish [22 / 100], running loss = 124.54718160629272, accuracy = 0.8268499970436096
# **********
# epoch 23
# Finish [50 / 235] batch, accuracy = 0.859375
# Finish [100 / 235] batch, accuracy = 0.8671875
# Finish [150 / 235] batch, accuracy = 0.83203125
# Finish [200 / 235] batch, accuracy = 0.81640625
# Finish [23 / 100], running loss = 123.6929287314415, accuracy = 0.8279833197593689
# **********
# epoch 24
# Finish [50 / 235] batch, accuracy = 0.81640625
# Finish [100 / 235] batch, accuracy = 0.84375
# Finish [150 / 235] batch, accuracy = 0.80859375
# Finish [200 / 235] batch, accuracy = 0.83203125
# Finish [24 / 100], running loss = 123.08951738476753, accuracy = 0.8285499811172485
# **********
# epoch 25
# Finish [50 / 235] batch, accuracy = 0.80859375
# Finish [100 / 235] batch, accuracy = 0.8046875
# Finish [150 / 235] batch, accuracy = 0.8125
# Finish [200 / 235] batch, accuracy = 0.8671875
# Finish [25 / 100], running loss = 122.16265806555748, accuracy = 0.8295000195503235
# **********
# epoch 26
# Finish [50 / 235] batch, accuracy = 0.83984375
# Finish [100 / 235] batch, accuracy = 0.83984375
# Finish [150 / 235] batch, accuracy = 0.84375
# Finish [200 / 235] batch, accuracy = 0.859375
# Finish [26 / 100], running loss = 121.54320213198662, accuracy = 0.82996666431427
# **********
# epoch 27
# Finish [50 / 235] batch, accuracy = 0.7890625
# Finish [100 / 235] batch, accuracy = 0.7734375
# Finish [150 / 235] batch, accuracy = 0.84375
# Finish [200 / 235] batch, accuracy = 0.82421875
# Finish [27 / 100], running loss = 120.78866627812386, accuracy = 0.8309833407402039
# **********
# epoch 28
# Finish [50 / 235] batch, accuracy = 0.8203125
# Finish [100 / 235] batch, accuracy = 0.83203125
# Finish [150 / 235] batch, accuracy = 0.83203125
# Finish [200 / 235] batch, accuracy = 0.83984375
# Finish [28 / 100], running loss = 120.11154752969742, accuracy = 0.8318166732788086
# **********
# epoch 29
# Finish [50 / 235] batch, accuracy = 0.83203125
# Finish [100 / 235] batch, accuracy = 0.8359375
# Finish [150 / 235] batch, accuracy = 0.83984375
# Finish [200 / 235] batch, accuracy = 0.80078125
# Finish [29 / 100], running loss = 119.50585028529167, accuracy = 0.8331500291824341
# **********
# epoch 30
# Finish [50 / 235] batch, accuracy = 0.8046875
# Finish [100 / 235] batch, accuracy = 0.8125
# Finish [150 / 235] batch, accuracy = 0.859375
# Finish [200 / 235] batch, accuracy = 0.828125
# Finish [30 / 100], running loss = 118.95687812566757, accuracy = 0.832883358001709
# **********
# epoch 31
# Finish [50 / 235] batch, accuracy = 0.81640625
# Finish [100 / 235] batch, accuracy = 0.828125
# Finish [150 / 235] batch, accuracy = 0.80859375
# Finish [200 / 235] batch, accuracy = 0.82421875
# Finish [31 / 100], running loss = 118.4177522957325, accuracy = 0.8337166905403137
# **********
# epoch 32
# Finish [50 / 235] batch, accuracy = 0.8125
# Finish [100 / 235] batch, accuracy = 0.8359375
# Finish [150 / 235] batch, accuracy = 0.8671875
# Finish [200 / 235] batch, accuracy = 0.8359375
# Finish [32 / 100], running loss = 117.91570770740509, accuracy = 0.8343833088874817
# **********
# epoch 33
# Finish [50 / 235] batch, accuracy = 0.78515625
# Finish [100 / 235] batch, accuracy = 0.796875
# Finish [150 / 235] batch, accuracy = 0.81640625
# Finish [200 / 235] batch, accuracy = 0.8046875
# Finish [33 / 100], running loss = 117.38615226745605, accuracy = 0.8344666957855225
# **********
# epoch 34
# Finish [50 / 235] batch, accuracy = 0.8203125
# Finish [100 / 235] batch, accuracy = 0.83203125
# Finish [150 / 235] batch, accuracy = 0.8359375
# Finish [200 / 235] batch, accuracy = 0.8125
# Finish [34 / 100], running loss = 116.97310453653336, accuracy = 0.8355166912078857
# **********
# epoch 35
# Finish [50 / 235] batch, accuracy = 0.8515625
# Finish [100 / 235] batch, accuracy = 0.80859375
# Finish [150 / 235] batch, accuracy = 0.8828125
# Finish [200 / 235] batch, accuracy = 0.84375
# Finish [35 / 100], running loss = 116.4230227470398, accuracy = 0.8361666798591614
# **********
# epoch 36
# Finish [50 / 235] batch, accuracy = 0.8125
# Finish [100 / 235] batch, accuracy = 0.84765625
# Finish [150 / 235] batch, accuracy = 0.8515625
# Finish [200 / 235] batch, accuracy = 0.83984375
# Finish [36 / 100], running loss = 116.00953486561775, accuracy = 0.8363999724388123
# **********
# epoch 37
# Finish [50 / 235] batch, accuracy = 0.8671875
# Finish [100 / 235] batch, accuracy = 0.83203125
# Finish [150 / 235] batch, accuracy = 0.828125
# Finish [200 / 235] batch, accuracy = 0.859375
# Finish [37 / 100], running loss = 115.68818840384483, accuracy = 0.8368666768074036
# **********
# epoch 38
# Finish [50 / 235] batch, accuracy = 0.83203125
# Finish [100 / 235] batch, accuracy = 0.83203125
# Finish [150 / 235] batch, accuracy = 0.8359375
# Finish [200 / 235] batch, accuracy = 0.86328125
# Finish [38 / 100], running loss = 115.22274515032768, accuracy = 0.8374500274658203
# **********
# epoch 39
# Finish [50 / 235] batch, accuracy = 0.8359375
# Finish [100 / 235] batch, accuracy = 0.875
# Finish [150 / 235] batch, accuracy = 0.81640625
# Finish [200 / 235] batch, accuracy = 0.859375
# Finish [39 / 100], running loss = 114.84632042050362, accuracy = 0.838100016117096
# **********
# epoch 40
# Finish [50 / 235] batch, accuracy = 0.8203125
# Finish [100 / 235] batch, accuracy = 0.79296875
# Finish [150 / 235] batch, accuracy = 0.83984375
# Finish [200 / 235] batch, accuracy = 0.80078125
# Finish [40 / 100], running loss = 114.52553704380989, accuracy = 0.8381666541099548
# **********
# epoch 41
# Finish [50 / 235] batch, accuracy = 0.83203125
# Finish [100 / 235] batch, accuracy = 0.859375
# Finish [150 / 235] batch, accuracy = 0.82421875
# Finish [200 / 235] batch, accuracy = 0.8203125
# Finish [41 / 100], running loss = 114.0591037273407, accuracy = 0.8389833569526672
# **********
# epoch 42
# Finish [50 / 235] batch, accuracy = 0.76953125
# Finish [100 / 235] batch, accuracy = 0.85546875
# Finish [150 / 235] batch, accuracy = 0.83984375
# Finish [200 / 235] batch, accuracy = 0.84765625
# Finish [42 / 100], running loss = 113.82402846217155, accuracy = 0.8388166427612305
# **********
# epoch 43
# Finish [50 / 235] batch, accuracy = 0.83203125
# Finish [100 / 235] batch, accuracy = 0.8359375
# Finish [150 / 235] batch, accuracy = 0.8046875
# Finish [200 / 235] batch, accuracy = 0.8515625
# Finish [43 / 100], running loss = 113.48160493373871, accuracy = 0.8397166728973389
# **********
# epoch 44
# Finish [50 / 235] batch, accuracy = 0.86328125
# Finish [100 / 235] batch, accuracy = 0.8203125
# Finish [150 / 235] batch, accuracy = 0.88671875
# Finish [200 / 235] batch, accuracy = 0.8125
# Finish [44 / 100], running loss = 113.1032078564167, accuracy = 0.8398500084877014
# **********
# epoch 45
# Finish [50 / 235] batch, accuracy = 0.828125
# Finish [100 / 235] batch, accuracy = 0.87890625
# Finish [150 / 235] batch, accuracy = 0.88671875
# Finish [200 / 235] batch, accuracy = 0.875
# Finish [45 / 100], running loss = 112.88022914528847, accuracy = 0.8399333357810974
# **********
# epoch 46
# Finish [50 / 235] batch, accuracy = 0.859375
# Finish [100 / 235] batch, accuracy = 0.8828125
# Finish [150 / 235] batch, accuracy = 0.81640625
# Finish [200 / 235] batch, accuracy = 0.83203125
# Finish [46 / 100], running loss = 112.47270289063454, accuracy = 0.8400166630744934
# **********
# epoch 47
# Finish [50 / 235] batch, accuracy = 0.81640625
# Finish [100 / 235] batch, accuracy = 0.8359375
# Finish [150 / 235] batch, accuracy = 0.8828125
# Finish [200 / 235] batch, accuracy = 0.84375
# Finish [47 / 100], running loss = 112.21357101202011, accuracy = 0.8414166569709778
# **********
# epoch 48
# Finish [50 / 235] batch, accuracy = 0.88671875
# Finish [100 / 235] batch, accuracy = 0.84375
# Finish [150 / 235] batch, accuracy = 0.82421875
# Finish [200 / 235] batch, accuracy = 0.87890625
# Finish [48 / 100], running loss = 111.86748996376991, accuracy = 0.8412833213806152
# **********
# epoch 49
# Finish [50 / 235] batch, accuracy = 0.83984375
# Finish [100 / 235] batch, accuracy = 0.83984375
# Finish [150 / 235] batch, accuracy = 0.85546875
# Finish [200 / 235] batch, accuracy = 0.86328125
# Finish [49 / 100], running loss = 111.56827411055565, accuracy = 0.8413333296775818
# **********
# epoch 50
# Finish [50 / 235] batch, accuracy = 0.86328125
# Finish [100 / 235] batch, accuracy = 0.85546875
# Finish [150 / 235] batch, accuracy = 0.859375
# Finish [200 / 235] batch, accuracy = 0.84375
# Finish [50 / 100], running loss = 111.42713195085526, accuracy = 0.8417166471481323
# **********
# epoch 51
# Finish [50 / 235] batch, accuracy = 0.8359375
# Finish [100 / 235] batch, accuracy = 0.88671875
# Finish [150 / 235] batch, accuracy = 0.83984375
# Finish [200 / 235] batch, accuracy = 0.87109375
# Finish [51 / 100], running loss = 111.16257351636887, accuracy = 0.8421499729156494
# **********
# epoch 52
# Finish [50 / 235] batch, accuracy = 0.8984375
# Finish [100 / 235] batch, accuracy = 0.89453125
# Finish [150 / 235] batch, accuracy = 0.83203125
# Finish [200 / 235] batch, accuracy = 0.8359375
# Finish [52 / 100], running loss = 110.75719639658928, accuracy = 0.8425499796867371
# **********
# epoch 53
# Finish [50 / 235] batch, accuracy = 0.84765625
# Finish [100 / 235] batch, accuracy = 0.82421875
# Finish [150 / 235] batch, accuracy = 0.84765625
# Finish [200 / 235] batch, accuracy = 0.83203125
# Finish [53 / 100], running loss = 110.56030738353729, accuracy = 0.8432833552360535
# **********
# epoch 54
# Finish [50 / 235] batch, accuracy = 0.8515625
# Finish [100 / 235] batch, accuracy = 0.796875
# Finish [150 / 235] batch, accuracy = 0.83203125
# Finish [200 / 235] batch, accuracy = 0.890625
# Finish [54 / 100], running loss = 110.36470267176628, accuracy = 0.8431333303451538
# **********
# epoch 55
# Finish [50 / 235] batch, accuracy = 0.84765625
# Finish [100 / 235] batch, accuracy = 0.87890625
# Finish [150 / 235] batch, accuracy = 0.8359375
# Finish [200 / 235] batch, accuracy = 0.8984375
# Finish [55 / 100], running loss = 110.1165826022625, accuracy = 0.8436333537101746
# **********
# epoch 56
# Finish [50 / 235] batch, accuracy = 0.84375
# Finish [100 / 235] batch, accuracy = 0.8671875
# Finish [150 / 235] batch, accuracy = 0.84765625
# Finish [200 / 235] batch, accuracy = 0.890625
# Finish [56 / 100], running loss = 109.96165347099304, accuracy = 0.8437833189964294
# **********
# epoch 57
# Finish [50 / 235] batch, accuracy = 0.83984375
# Finish [100 / 235] batch, accuracy = 0.8359375
# Finish [150 / 235] batch, accuracy = 0.85546875
# Finish [200 / 235] batch, accuracy = 0.8125
# Finish [57 / 100], running loss = 109.6778607070446, accuracy = 0.8440333604812622
# **********
# epoch 58
# Finish [50 / 235] batch, accuracy = 0.8828125
# Finish [100 / 235] batch, accuracy = 0.84375
# Finish [150 / 235] batch, accuracy = 0.8515625
# Finish [200 / 235] batch, accuracy = 0.85546875
# Finish [58 / 100], running loss = 109.41439521312714, accuracy = 0.8444499969482422
# **********
# epoch 59
# Finish [50 / 235] batch, accuracy = 0.81640625
# Finish [100 / 235] batch, accuracy = 0.8359375
# Finish [150 / 235] batch, accuracy = 0.7734375
# Finish [200 / 235] batch, accuracy = 0.8515625
# Finish [59 / 100], running loss = 109.15957778692245, accuracy = 0.8446833491325378
# **********
# epoch 60
# Finish [50 / 235] batch, accuracy = 0.8125
# Finish [100 / 235] batch, accuracy = 0.87890625
# Finish [150 / 235] batch, accuracy = 0.85546875
# Finish [200 / 235] batch, accuracy = 0.83203125
# Finish [60 / 100], running loss = 109.03092530369759, accuracy = 0.8448500037193298
# **********
# epoch 61
# Finish [50 / 235] batch, accuracy = 0.828125
# Finish [100 / 235] batch, accuracy = 0.85546875
# Finish [150 / 235] batch, accuracy = 0.83203125
# Finish [200 / 235] batch, accuracy = 0.8671875
# Finish [61 / 100], running loss = 108.70117002725601, accuracy = 0.8453500270843506
# **********
# epoch 62
# Finish [50 / 235] batch, accuracy = 0.8203125
# Finish [100 / 235] batch, accuracy = 0.83984375
# Finish [150 / 235] batch, accuracy = 0.86328125
# Finish [200 / 235] batch, accuracy = 0.86328125
# Finish [62 / 100], running loss = 108.59723794460297, accuracy = 0.8452666401863098
# **********
# epoch 63
# Finish [50 / 235] batch, accuracy = 0.85546875
# Finish [100 / 235] batch, accuracy = 0.85546875
# Finish [150 / 235] batch, accuracy = 0.86328125
# Finish [200 / 235] batch, accuracy = 0.87890625
# Finish [63 / 100], running loss = 108.45305943489075, accuracy = 0.8463500142097473
# **********
# epoch 64
# Finish [50 / 235] batch, accuracy = 0.80078125
# Finish [100 / 235] batch, accuracy = 0.828125
# Finish [150 / 235] batch, accuracy = 0.85546875
# Finish [200 / 235] batch, accuracy = 0.87890625
# Finish [64 / 100], running loss = 108.23699256777763, accuracy = 0.8459166884422302
# **********
# epoch 65
# Finish [50 / 235] batch, accuracy = 0.875
# Finish [100 / 235] batch, accuracy = 0.81640625
# Finish [150 / 235] batch, accuracy = 0.8359375
# Finish [200 / 235] batch, accuracy = 0.84375
# Finish [65 / 100], running loss = 108.09834775328636, accuracy = 0.8462499976158142
# **********
# epoch 66
# Finish [50 / 235] batch, accuracy = 0.86328125
# Finish [100 / 235] batch, accuracy = 0.8515625
# Finish [150 / 235] batch, accuracy = 0.859375
# Finish [200 / 235] batch, accuracy = 0.875
# Finish [66 / 100], running loss = 107.96201318502426, accuracy = 0.8463833332061768
# **********
# epoch 67
# Finish [50 / 235] batch, accuracy = 0.8671875
# Finish [100 / 235] batch, accuracy = 0.81640625
# Finish [150 / 235] batch, accuracy = 0.8359375
# Finish [200 / 235] batch, accuracy = 0.80859375
# Finish [67 / 100], running loss = 107.66889476776123, accuracy = 0.8462499976158142
# **********
# epoch 68
# Finish [50 / 235] batch, accuracy = 0.83203125
# Finish [100 / 235] batch, accuracy = 0.84765625
# Finish [150 / 235] batch, accuracy = 0.84765625
# Finish [200 / 235] batch, accuracy = 0.81640625
# Finish [68 / 100], running loss = 107.5247893333435, accuracy = 0.8459500074386597
# **********
# epoch 69
# Finish [50 / 235] batch, accuracy = 0.84765625
# Finish [100 / 235] batch, accuracy = 0.87109375
# Finish [150 / 235] batch, accuracy = 0.8828125
# Finish [200 / 235] batch, accuracy = 0.86328125
# Finish [69 / 100], running loss = 107.32887560129166, accuracy = 0.8468666672706604
# **********
# epoch 70
# Finish [50 / 235] batch, accuracy = 0.8359375
# Finish [100 / 235] batch, accuracy = 0.8203125
# Finish [150 / 235] batch, accuracy = 0.83984375
# Finish [200 / 235] batch, accuracy = 0.875
# Finish [70 / 100], running loss = 107.13739722967148, accuracy = 0.8467833399772644
# **********
# epoch 71
# Finish [50 / 235] batch, accuracy = 0.8359375
# Finish [100 / 235] batch, accuracy = 0.875
# Finish [150 / 235] batch, accuracy = 0.8515625
# Finish [200 / 235] batch, accuracy = 0.83984375
# Finish [71 / 100], running loss = 106.97899010777473, accuracy = 0.8468666672706604
# **********
# epoch 72
# Finish [50 / 235] batch, accuracy = 0.86328125
# Finish [100 / 235] batch, accuracy = 0.84375
# Finish [150 / 235] batch, accuracy = 0.87109375
# Finish [200 / 235] batch, accuracy = 0.84765625
# Finish [72 / 100], running loss = 106.9464465379715, accuracy = 0.8478833436965942
# **********
# epoch 73
# Finish [50 / 235] batch, accuracy = 0.87890625
# Finish [100 / 235] batch, accuracy = 0.83984375
# Finish [150 / 235] batch, accuracy = 0.8671875
# Finish [200 / 235] batch, accuracy = 0.8125
# Finish [73 / 100], running loss = 106.678243547678, accuracy = 0.8475666642189026
# **********
# epoch 74
# Finish [50 / 235] batch, accuracy = 0.875
# Finish [100 / 235] batch, accuracy = 0.859375
# Finish [150 / 235] batch, accuracy = 0.81640625
# Finish [200 / 235] batch, accuracy = 0.8515625
# Finish [74 / 100], running loss = 106.5316253900528, accuracy = 0.8478833436965942
# **********
# epoch 75
# Finish [50 / 235] batch, accuracy = 0.82421875
# Finish [100 / 235] batch, accuracy = 0.83984375
# Finish [150 / 235] batch, accuracy = 0.84765625
# Finish [200 / 235] batch, accuracy = 0.8359375
# Finish [75 / 100], running loss = 106.34294146299362, accuracy = 0.8477166891098022
# **********
# epoch 76
# Finish [50 / 235] batch, accuracy = 0.828125
# Finish [100 / 235] batch, accuracy = 0.828125
# Finish [150 / 235] batch, accuracy = 0.8515625
# Finish [200 / 235] batch, accuracy = 0.8125
# Finish [76 / 100], running loss = 106.30913037061691, accuracy = 0.8481000065803528
# **********
# epoch 77
# Finish [50 / 235] batch, accuracy = 0.86328125
# Finish [100 / 235] batch, accuracy = 0.83203125
# Finish [150 / 235] batch, accuracy = 0.84765625
# Finish [200 / 235] batch, accuracy = 0.88671875
# Finish [77 / 100], running loss = 106.07528471946716, accuracy = 0.8479666709899902
# **********
# epoch 78
# Finish [50 / 235] batch, accuracy = 0.84765625
# Finish [100 / 235] batch, accuracy = 0.85546875
# Finish [150 / 235] batch, accuracy = 0.83203125
# Finish [200 / 235] batch, accuracy = 0.8203125
# Finish [78 / 100], running loss = 105.92637431621552, accuracy = 0.848466694355011
# **********
# epoch 79
# Finish [50 / 235] batch, accuracy = 0.85546875
# Finish [100 / 235] batch, accuracy = 0.8359375
# Finish [150 / 235] batch, accuracy = 0.85546875
# Finish [200 / 235] batch, accuracy = 0.87890625
# Finish [79 / 100], running loss = 105.79882377386093, accuracy = 0.8485333323478699
# **********
# epoch 80
# Finish [50 / 235] batch, accuracy = 0.8359375
# Finish [100 / 235] batch, accuracy = 0.86328125
# Finish [150 / 235] batch, accuracy = 0.85546875
# Finish [200 / 235] batch, accuracy = 0.8359375
# Finish [80 / 100], running loss = 105.73890581727028, accuracy = 0.848883330821991
# **********
# epoch 81
# Finish [50 / 235] batch, accuracy = 0.85546875
# Finish [100 / 235] batch, accuracy = 0.8359375
# Finish [150 / 235] batch, accuracy = 0.8671875
# Finish [200 / 235] batch, accuracy = 0.8828125
# Finish [81 / 100], running loss = 105.50995010137558, accuracy = 0.8490333557128906
# **********
# epoch 82
# Finish [50 / 235] batch, accuracy = 0.88671875
# Finish [100 / 235] batch, accuracy = 0.80859375
# Finish [150 / 235] batch, accuracy = 0.83203125
# Finish [200 / 235] batch, accuracy = 0.8671875
# Finish [82 / 100], running loss = 105.46852979063988, accuracy = 0.8494333624839783
# **********
# epoch 83
# Finish [50 / 235] batch, accuracy = 0.82421875
# Finish [100 / 235] batch, accuracy = 0.875
# Finish [150 / 235] batch, accuracy = 0.83203125
# Finish [200 / 235] batch, accuracy = 0.82421875
# Finish [83 / 100], running loss = 105.27010783553123, accuracy = 0.8493166565895081
# **********
# epoch 84
# Finish [50 / 235] batch, accuracy = 0.86328125
# Finish [100 / 235] batch, accuracy = 0.8515625
# Finish [150 / 235] batch, accuracy = 0.859375
# Finish [200 / 235] batch, accuracy = 0.87890625
# Finish [84 / 100], running loss = 105.08301761746407, accuracy = 0.849566638469696
# **********
# epoch 85
# Finish [50 / 235] batch, accuracy = 0.86328125
# Finish [100 / 235] batch, accuracy = 0.86328125
# Finish [150 / 235] batch, accuracy = 0.85546875
# Finish [200 / 235] batch, accuracy = 0.82421875
# Finish [85 / 100], running loss = 105.0067945420742, accuracy = 0.8494833111763
# **********
# epoch 86
# Finish [50 / 235] batch, accuracy = 0.8359375
# Finish [100 / 235] batch, accuracy = 0.8671875
# Finish [150 / 235] batch, accuracy = 0.87890625
# Finish [200 / 235] batch, accuracy = 0.84375
# Finish [86 / 100], running loss = 104.8927915096283, accuracy = 0.8497166633605957
# **********
# epoch 87
# Finish [50 / 235] batch, accuracy = 0.83984375
# Finish [100 / 235] batch, accuracy = 0.8671875
# Finish [150 / 235] batch, accuracy = 0.8046875
# Finish [200 / 235] batch, accuracy = 0.87109375
# Finish [87 / 100], running loss = 104.79449898004532, accuracy = 0.8495833277702332
# **********
# epoch 88
# Finish [50 / 235] batch, accuracy = 0.87890625
# Finish [100 / 235] batch, accuracy = 0.875
# Finish [150 / 235] batch, accuracy = 0.84765625
# Finish [200 / 235] batch, accuracy = 0.81640625
# Finish [88 / 100], running loss = 104.70256158709526, accuracy = 0.849399983882904
# **********
# epoch 89
# Finish [50 / 235] batch, accuracy = 0.83203125
# Finish [100 / 235] batch, accuracy = 0.86328125
# Finish [150 / 235] batch, accuracy = 0.859375
# Finish [200 / 235] batch, accuracy = 0.859375
# Finish [89 / 100], running loss = 104.60336351394653, accuracy = 0.8496333360671997
# **********
# epoch 90
# Finish [50 / 235] batch, accuracy = 0.85546875
# Finish [100 / 235] batch, accuracy = 0.8828125
# Finish [150 / 235] batch, accuracy = 0.8515625
# Finish [200 / 235] batch, accuracy = 0.8515625
# Finish [90 / 100], running loss = 104.4790073633194, accuracy = 0.8502500057220459
# **********
# epoch 91
# Finish [50 / 235] batch, accuracy = 0.81640625
# Finish [100 / 235] batch, accuracy = 0.8515625
# Finish [150 / 235] batch, accuracy = 0.81640625
# Finish [200 / 235] batch, accuracy = 0.84765625
# Finish [91 / 100], running loss = 104.28874212503433, accuracy = 0.8501833081245422
# **********
# epoch 92
# Finish [50 / 235] batch, accuracy = 0.86328125
# Finish [100 / 235] batch, accuracy = 0.8515625
# Finish [150 / 235] batch, accuracy = 0.86328125
# Finish [200 / 235] batch, accuracy = 0.84375
# Finish [92 / 100], running loss = 104.26097077131271, accuracy = 0.8503333330154419
# **********
# epoch 93
# Finish [50 / 235] batch, accuracy = 0.80859375
# Finish [100 / 235] batch, accuracy = 0.828125
# Finish [150 / 235] batch, accuracy = 0.8203125
# Finish [200 / 235] batch, accuracy = 0.83984375
# Finish [93 / 100], running loss = 104.11915069818497, accuracy = 0.8503999710083008
# **********
# epoch 94
# Finish [50 / 235] batch, accuracy = 0.83203125
# Finish [100 / 235] batch, accuracy = 0.8828125
# Finish [150 / 235] batch, accuracy = 0.84375
# Finish [200 / 235] batch, accuracy = 0.859375
# Finish [94 / 100], running loss = 104.02802097797394, accuracy = 0.8507166504859924
# **********
# epoch 95
# Finish [50 / 235] batch, accuracy = 0.8359375
# Finish [100 / 235] batch, accuracy = 0.8203125
# Finish [150 / 235] batch, accuracy = 0.85546875
# Finish [200 / 235] batch, accuracy = 0.859375
# Finish [95 / 100], running loss = 103.84732204675674, accuracy = 0.8506666421890259
# **********
# epoch 96
# Finish [50 / 235] batch, accuracy = 0.8359375
# Finish [100 / 235] batch, accuracy = 0.86328125
# Finish [150 / 235] batch, accuracy = 0.82421875
# Finish [200 / 235] batch, accuracy = 0.88671875
# Finish [96 / 100], running loss = 103.78652694821358, accuracy = 0.850849986076355
# **********
# epoch 97
# Finish [50 / 235] batch, accuracy = 0.859375
# Finish [100 / 235] batch, accuracy = 0.85546875
# Finish [150 / 235] batch, accuracy = 0.86328125
# Finish [200 / 235] batch, accuracy = 0.859375
# Finish [97 / 100], running loss = 103.65544095635414, accuracy = 0.8506166934967041
# **********
# epoch 98
# Finish [50 / 235] batch, accuracy = 0.87890625
# Finish [100 / 235] batch, accuracy = 0.84375
# Finish [150 / 235] batch, accuracy = 0.859375
# Finish [200 / 235] batch, accuracy = 0.83984375
# Finish [98 / 100], running loss = 103.58753874897957, accuracy = 0.8510000109672546
# **********
# epoch 99
# Finish [50 / 235] batch, accuracy = 0.828125
# Finish [100 / 235] batch, accuracy = 0.85546875
# Finish [150 / 235] batch, accuracy = 0.828125
# Finish [200 / 235] batch, accuracy = 0.859375
# Finish [99 / 100], running loss = 103.47403171658516, accuracy = 0.8513000011444092
# **********
# epoch 100
# Finish [50 / 235] batch, accuracy = 0.86328125
# Finish [100 / 235] batch, accuracy = 0.8125
# Finish [150 / 235] batch, accuracy = 0.8828125
# Finish [200 / 235] batch, accuracy = 0.8203125
# Finish [100 / 100], running loss = 103.38222494721413, accuracy = 0.8514000177383423

# %%
for i in train_loader:
    print(i)
    break
# Out:
# [tensor([[[[0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0039],
#           ...,
#           [0.0000, 0.0000, 0.2039,  ..., 0.7137, 0.7961, 0.3137],
#           [0.0000, 0.0000, 0.0000,  ..., 0.3608, 0.3686, 0.0314],
#           [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000]]],
#
#
#         [[[0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           ...,
#           [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000]]],
#
#
#         [[[0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0118, 0.0000],
#           ...,
#           [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000]]],
#
#
#         ...,
#
#
#         [[[0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           ...,
#           [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000]]],
#
#
#         [[[0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000,  ..., 0.3882, 0.3412, 0.0000],
#           [0.0000, 0.0000, 0.0000,  ..., 0.8863, 0.9569, 0.0000],
#           ...,
#           [0.0000, 0.0118, 0.5176,  ..., 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000]]],
#
#
#         [[[0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           ...,
#           [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000]]]]), tensor([9, 3, 9, 1, 7, 9, 4, 4, 2, 9, 4, 9, 4, 9, 2, 5, 7, 7, 4, 5, 4, 9, 1, 5,
#         2, 4, 6, 1, 0, 0, 1, 8, 5, 2, 2, 5, 8, 6, 2, 1, 7, 8, 7, 4, 8, 1, 2, 0,
#         2, 1, 3, 8, 7, 2, 6, 0, 8, 5, 5, 2, 0, 6, 9, 4])]

# %%
i[0].numpy().shape, i[1].numpy().shape
# batch size 64
# Out:
# ((64, 1, 28, 28), (64,))

# %%
i[0].view(64, -1).shape
# Out:
# torch.Size([64, 784])
