# %%
import time
import torch
import torch.nn.functional as F
from torch import nn
from torch.utils.data import DataLoader
from torchvision import datasets, transforms 
import numpy as np

# %%
# hyper params
batch_size = 256
learning_rate = 1e-2
num_epochs = 100

# %%
# downlaod Fashion MNIST dataset
train_dataset = datasets.FashionMNIST(
    root='../datasets', train=True, transform=transforms.ToTensor(), download=True)
test_dataset = datasets.FashionMNIST(
    root='../datasets', train=False, transform=transforms.ToTensor())

train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

# %%
# check about data
len(train_dataset), len(train_loader)
# for one epoch, we train all the data once. In one epoch we use "for" to data loader to traverse all batchs.
# Here one epoch we train 60000 records, in one epoch we run 938 batchs, each batch contains 64 records(batch size)
# Out:
# (60000, 235)

# %%
# logistic regression model
class logistic_regression(nn.Module):
    def __init__(self, in_dim, n_class):
        super(logistic_regression, self).__init__()
        self.fc = nn.Linear(in_dim, n_class)

    def forward(self, x):
        out = self.fc(x)
        #out = torch.sigmoid(out)
        return out

# %%
if __name__ == "__main__":
    # init 
    model = logistic_regression(28 * 28, 10)
    use_gpu = torch.cuda.is_available()
    if use_gpu:
        model = model.cuda()
    criterion = nn.CrossEntropyLoss() # loss function
    optimizer = torch.optim.SGD(model.parameters(), lr=learning_rate)

    # training
    print("Begin training...")

    for epoch in range(num_epochs):
        print("*" * 10)
        print(f"epoch {epoch + 1}")
        since = time.time()
        running_loss = 0.
        running_acc = 0.

        model.train()
        for i, data in enumerate(train_loader):
            img, label = data
            img = img.view(img.size(0), -1)
            if use_gpu:
                img = img.cuda()
                label = label.cuda()

            # forward
            out = model(img)
            loss = criterion(out, label)
            running_loss += loss.item()
            _, pred = torch.max(out, 1)
            running_acc += (pred == label).float().sum()

            # backward
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            # log
            if (i+1) % 50 == 0:
                print(f"Finish [{i+1} / {len(train_loader)}] batch, accuracy = {(pred == label).float().mean()}")
        print(f"Finish [{epoch+1} / {num_epochs}], running loss = {running_loss}, accuracy = {running_acc / len(train_dataset)}")
# Out:
# Begin training...
# **********
# epoch 1
# Finish [50 / 235] batch, accuracy = 0.609375
# Finish [100 / 235] batch, accuracy = 0.66796875
# Finish [150 / 235] batch, accuracy = 0.65234375
# Finish [200 / 235] batch, accuracy = 0.71484375
# Finish [1 / 100], running loss = 322.783565223217, accuracy = 0.6230999827384949
# **********
# epoch 2
# Finish [50 / 235] batch, accuracy = 0.625
# Finish [100 / 235] batch, accuracy = 0.6640625
# Finish [150 / 235] batch, accuracy = 0.7578125
# Finish [200 / 235] batch, accuracy = 0.70703125
# Finish [2 / 100], running loss = 215.62884092330933, accuracy = 0.7110499739646912
# **********
# epoch 3
# Finish [50 / 235] batch, accuracy = 0.7734375
# Finish [100 / 235] batch, accuracy = 0.73828125
# Finish [150 / 235] batch, accuracy = 0.75390625
# Finish [200 / 235] batch, accuracy = 0.78125
# Finish [3 / 100], running loss = 188.87035858631134, accuracy = 0.7460333108901978
# **********
# epoch 4
# Finish [50 / 235] batch, accuracy = 0.75390625
# Finish [100 / 235] batch, accuracy = 0.765625
# Finish [150 / 235] batch, accuracy = 0.77734375
# Finish [200 / 235] batch, accuracy = 0.796875
# Finish [4 / 100], running loss = 174.71638244390488, accuracy = 0.7644166946411133
# **********
# epoch 5
# Finish [50 / 235] batch, accuracy = 0.76953125
# Finish [100 / 235] batch, accuracy = 0.734375
# Finish [150 / 235] batch, accuracy = 0.7890625
# Finish [200 / 235] batch, accuracy = 0.74609375
# Finish [5 / 100], running loss = 165.36899155378342, accuracy = 0.777899980545044
# **********
# epoch 6
# Finish [50 / 235] batch, accuracy = 0.77734375
# Finish [100 / 235] batch, accuracy = 0.796875
# Finish [150 / 235] batch, accuracy = 0.796875
# Finish [200 / 235] batch, accuracy = 0.79296875
# Finish [6 / 100], running loss = 158.51461911201477, accuracy = 0.7873333096504211
# **********
# epoch 7
# Finish [50 / 235] batch, accuracy = 0.8125
# Finish [100 / 235] batch, accuracy = 0.8359375
# Finish [150 / 235] batch, accuracy = 0.80078125
# Finish [200 / 235] batch, accuracy = 0.7734375
# Finish [7 / 100], running loss = 153.2868539094925, accuracy = 0.7939500212669373
# **********
# epoch 8
# Finish [50 / 235] batch, accuracy = 0.8359375
# Finish [100 / 235] batch, accuracy = 0.8359375
# Finish [150 / 235] batch, accuracy = 0.796875
# Finish [200 / 235] batch, accuracy = 0.796875
# Finish [8 / 100], running loss = 149.04829555749893, accuracy = 0.7987666726112366
# **********
# epoch 9
# Finish [50 / 235] batch, accuracy = 0.7890625
# Finish [100 / 235] batch, accuracy = 0.78515625
# Finish [150 / 235] batch, accuracy = 0.8515625
# Finish [200 / 235] batch, accuracy = 0.828125
# Finish [9 / 100], running loss = 145.5302385687828, accuracy = 0.8031166791915894
# **********
# epoch 10
# Finish [50 / 235] batch, accuracy = 0.84375
# Finish [100 / 235] batch, accuracy = 0.7734375
# Finish [150 / 235] batch, accuracy = 0.796875
# Finish [200 / 235] batch, accuracy = 0.82421875
# Finish [10 / 100], running loss = 142.55509197711945, accuracy = 0.8067833185195923
# **********
# epoch 11
# Finish [50 / 235] batch, accuracy = 0.78515625
# Finish [100 / 235] batch, accuracy = 0.83984375
# Finish [150 / 235] batch, accuracy = 0.7890625
# Finish [200 / 235] batch, accuracy = 0.84375
# Finish [11 / 100], running loss = 139.87876600027084, accuracy = 0.8085833191871643
# **********
# epoch 12
# Finish [50 / 235] batch, accuracy = 0.765625
# Finish [100 / 235] batch, accuracy = 0.8125
# Finish [150 / 235] batch, accuracy = 0.83984375
# Finish [200 / 235] batch, accuracy = 0.80859375
# Finish [12 / 100], running loss = 137.76166412234306, accuracy = 0.8117166757583618
# **********
# epoch 13
# Finish [50 / 235] batch, accuracy = 0.81640625
# Finish [100 / 235] batch, accuracy = 0.80078125
# Finish [150 / 235] batch, accuracy = 0.82421875
# Finish [200 / 235] batch, accuracy = 0.78515625
# Finish [13 / 100], running loss = 135.7082544863224, accuracy = 0.8137000203132629
# **********
# epoch 14
# Finish [50 / 235] batch, accuracy = 0.78515625
# Finish [100 / 235] batch, accuracy = 0.86328125
# Finish [150 / 235] batch, accuracy = 0.8203125
# Finish [200 / 235] batch, accuracy = 0.8203125
# Finish [14 / 100], running loss = 133.92564198374748, accuracy = 0.8156833052635193
# **********
# epoch 15
# Finish [50 / 235] batch, accuracy = 0.88671875
# Finish [100 / 235] batch, accuracy = 0.83984375
# Finish [150 / 235] batch, accuracy = 0.81640625
# Finish [200 / 235] batch, accuracy = 0.83203125
# Finish [15 / 100], running loss = 132.38193568587303, accuracy = 0.8177000284194946
# **********
# epoch 16
# Finish [50 / 235] batch, accuracy = 0.80078125
# Finish [100 / 235] batch, accuracy = 0.8359375
# Finish [150 / 235] batch, accuracy = 0.7890625
# Finish [200 / 235] batch, accuracy = 0.78515625
# Finish [16 / 100], running loss = 130.89620825648308, accuracy = 0.8192833065986633
# **********
# epoch 17
# Finish [50 / 235] batch, accuracy = 0.83203125
# Finish [100 / 235] batch, accuracy = 0.828125
# Finish [150 / 235] batch, accuracy = 0.81640625
# Finish [200 / 235] batch, accuracy = 0.8125
# Finish [17 / 100], running loss = 129.57582545280457, accuracy = 0.8209999799728394
# **********
# epoch 18
# Finish [50 / 235] batch, accuracy = 0.83203125
# Finish [100 / 235] batch, accuracy = 0.8046875
# Finish [150 / 235] batch, accuracy = 0.83203125
# Finish [200 / 235] batch, accuracy = 0.80859375
# Finish [18 / 100], running loss = 128.32868552207947, accuracy = 0.8226333260536194
# **********
# epoch 19
# Finish [50 / 235] batch, accuracy = 0.82421875
# Finish [100 / 235] batch, accuracy = 0.83984375
# Finish [150 / 235] batch, accuracy = 0.84375
# Finish [200 / 235] batch, accuracy = 0.80078125
# Finish [19 / 100], running loss = 127.21652257442474, accuracy = 0.8241166472434998
# **********
# epoch 20
# Finish [50 / 235] batch, accuracy = 0.83984375
# Finish [100 / 235] batch, accuracy = 0.80078125
# Finish [150 / 235] batch, accuracy = 0.78515625
# Finish [200 / 235] batch, accuracy = 0.82421875
# Finish [20 / 100], running loss = 126.17806121706963, accuracy = 0.8247833251953125
# **********
# epoch 21
# Finish [50 / 235] batch, accuracy = 0.86328125
# Finish [100 / 235] batch, accuracy = 0.81640625
# Finish [150 / 235] batch, accuracy = 0.83203125
# Finish [200 / 235] batch, accuracy = 0.83984375
# Finish [21 / 100], running loss = 125.27837678790092, accuracy = 0.8263499736785889
# **********
# epoch 22
# Finish [50 / 235] batch, accuracy = 0.8359375
# Finish [100 / 235] batch, accuracy = 0.84375
# Finish [150 / 235] batch, accuracy = 0.78515625
# Finish [200 / 235] batch, accuracy = 0.8203125
# Finish [22 / 100], running loss = 124.37073749303818, accuracy = 0.8277000188827515
# **********
# epoch 23
# Finish [50 / 235] batch, accuracy = 0.84375
# Finish [100 / 235] batch, accuracy = 0.8125
# Finish [150 / 235] batch, accuracy = 0.8203125
# Finish [200 / 235] batch, accuracy = 0.8046875
# Finish [23 / 100], running loss = 123.46244433522224, accuracy = 0.8277999758720398
# **********
# epoch 24
# Finish [50 / 235] batch, accuracy = 0.85546875
# Finish [100 / 235] batch, accuracy = 0.82421875
# Finish [150 / 235] batch, accuracy = 0.84375
# Finish [200 / 235] batch, accuracy = 0.85546875
# Finish [24 / 100], running loss = 122.7614272236824, accuracy = 0.8289999961853027
# **********
# epoch 25
# Finish [50 / 235] batch, accuracy = 0.83203125
# Finish [100 / 235] batch, accuracy = 0.80078125
# Finish [150 / 235] batch, accuracy = 0.8046875
# Finish [200 / 235] batch, accuracy = 0.8359375
# Finish [25 / 100], running loss = 121.97400614619255, accuracy = 0.829800009727478
# **********
# epoch 26
# Finish [50 / 235] batch, accuracy = 0.87109375
# Finish [100 / 235] batch, accuracy = 0.8046875
# Finish [150 / 235] batch, accuracy = 0.8515625
# Finish [200 / 235] batch, accuracy = 0.8203125
# Finish [26 / 100], running loss = 121.39789780974388, accuracy = 0.8303333520889282
# **********
# epoch 27
# Finish [50 / 235] batch, accuracy = 0.85546875
# Finish [100 / 235] batch, accuracy = 0.81640625
# Finish [150 / 235] batch, accuracy = 0.85546875
# Finish [200 / 235] batch, accuracy = 0.84375
# Finish [27 / 100], running loss = 120.68475967645645, accuracy = 0.8309166431427002
# **********
# epoch 28
# Finish [50 / 235] batch, accuracy = 0.8125
# Finish [100 / 235] batch, accuracy = 0.8203125
# Finish [150 / 235] batch, accuracy = 0.86328125
# Finish [200 / 235] batch, accuracy = 0.8359375
# Finish [28 / 100], running loss = 119.95703276991844, accuracy = 0.8320333361625671
# **********
# epoch 29
# Finish [50 / 235] batch, accuracy = 0.8359375
# Finish [100 / 235] batch, accuracy = 0.8359375
# Finish [150 / 235] batch, accuracy = 0.83203125
# Finish [200 / 235] batch, accuracy = 0.875
# Finish [29 / 100], running loss = 119.46306326985359, accuracy = 0.8322333097457886
# **********
# epoch 30
# Finish [50 / 235] batch, accuracy = 0.80859375
# Finish [100 / 235] batch, accuracy = 0.87109375
# Finish [150 / 235] batch, accuracy = 0.84375
# Finish [200 / 235] batch, accuracy = 0.8203125
# Finish [30 / 100], running loss = 118.86526891589165, accuracy = 0.8327833414077759
# **********
# epoch 31
# Finish [50 / 235] batch, accuracy = 0.8359375
# Finish [100 / 235] batch, accuracy = 0.80859375
# Finish [150 / 235] batch, accuracy = 0.81640625
# Finish [200 / 235] batch, accuracy = 0.87109375
# Finish [31 / 100], running loss = 118.30353662371635, accuracy = 0.8339499831199646
# **********
# epoch 32
# Finish [50 / 235] batch, accuracy = 0.8984375
# Finish [100 / 235] batch, accuracy = 0.828125
# Finish [150 / 235] batch, accuracy = 0.8203125
# Finish [200 / 235] batch, accuracy = 0.859375
# Finish [32 / 100], running loss = 117.84433495998383, accuracy = 0.8340833187103271
# **********
# epoch 33
# Finish [50 / 235] batch, accuracy = 0.7734375
# Finish [100 / 235] batch, accuracy = 0.8359375
# Finish [150 / 235] batch, accuracy = 0.875
# Finish [200 / 235] batch, accuracy = 0.8515625
# Finish [33 / 100], running loss = 117.3564915060997, accuracy = 0.8346999883651733
# **********
# epoch 34
# Finish [50 / 235] batch, accuracy = 0.83984375
# Finish [100 / 235] batch, accuracy = 0.8359375
# Finish [150 / 235] batch, accuracy = 0.8046875
# Finish [200 / 235] batch, accuracy = 0.85546875
# Finish [34 / 100], running loss = 116.80459251999855, accuracy = 0.8354666829109192
# **********
# epoch 35
# Finish [50 / 235] batch, accuracy = 0.796875
# Finish [100 / 235] batch, accuracy = 0.86328125
# Finish [150 / 235] batch, accuracy = 0.8203125
# Finish [200 / 235] batch, accuracy = 0.83984375
# Finish [35 / 100], running loss = 116.30789193511009, accuracy = 0.8363333344459534
# **********
# epoch 36
# Finish [50 / 235] batch, accuracy = 0.81640625
# Finish [100 / 235] batch, accuracy = 0.84765625
# Finish [150 / 235] batch, accuracy = 0.79296875
# Finish [200 / 235] batch, accuracy = 0.83203125
# Finish [36 / 100], running loss = 115.94414669275284, accuracy = 0.8363999724388123
# **********
# epoch 37
# Finish [50 / 235] batch, accuracy = 0.8515625
# Finish [100 / 235] batch, accuracy = 0.87890625
# Finish [150 / 235] batch, accuracy = 0.82421875
# Finish [200 / 235] batch, accuracy = 0.84375
# Finish [37 / 100], running loss = 115.51200741529465, accuracy = 0.8373000025749207
# **********
# epoch 38
# Finish [50 / 235] batch, accuracy = 0.828125
# Finish [100 / 235] batch, accuracy = 0.8359375
# Finish [150 / 235] batch, accuracy = 0.85546875
# Finish [200 / 235] batch, accuracy = 0.87109375
# Finish [38 / 100], running loss = 115.09174302220345, accuracy = 0.8378666639328003
# **********
# epoch 39
# Finish [50 / 235] batch, accuracy = 0.8125
# Finish [100 / 235] batch, accuracy = 0.828125
# Finish [150 / 235] batch, accuracy = 0.84375
# Finish [200 / 235] batch, accuracy = 0.87890625
# Finish [39 / 100], running loss = 114.71640926599503, accuracy = 0.8376500010490417
# **********
# epoch 40
# Finish [50 / 235] batch, accuracy = 0.84375
# Finish [100 / 235] batch, accuracy = 0.82421875
# Finish [150 / 235] batch, accuracy = 0.828125
# Finish [200 / 235] batch, accuracy = 0.83203125
# Finish [40 / 100], running loss = 114.37398013472557, accuracy = 0.8382999897003174
# **********
# epoch 41
# Finish [50 / 235] batch, accuracy = 0.80078125
# Finish [100 / 235] batch, accuracy = 0.85546875
# Finish [150 / 235] batch, accuracy = 0.8515625
# Finish [200 / 235] batch, accuracy = 0.8359375
# Finish [41 / 100], running loss = 114.07451903820038, accuracy = 0.838949978351593
# **********
# epoch 42
# Finish [50 / 235] batch, accuracy = 0.8359375
# Finish [100 / 235] batch, accuracy = 0.8671875
# Finish [150 / 235] batch, accuracy = 0.80859375
# Finish [200 / 235] batch, accuracy = 0.7890625
# Finish [42 / 100], running loss = 113.73947018384933, accuracy = 0.8390499949455261
# **********
# epoch 43
# Finish [50 / 235] batch, accuracy = 0.84765625
# Finish [100 / 235] batch, accuracy = 0.8359375
# Finish [150 / 235] batch, accuracy = 0.8359375
# Finish [200 / 235] batch, accuracy = 0.84375
# Finish [43 / 100], running loss = 113.34463658928871, accuracy = 0.839033305644989
# **********
# epoch 44
# Finish [50 / 235] batch, accuracy = 0.8515625
# Finish [100 / 235] batch, accuracy = 0.82421875
# Finish [150 / 235] batch, accuracy = 0.8203125
# Finish [200 / 235] batch, accuracy = 0.8203125
# Finish [44 / 100], running loss = 112.97886443138123, accuracy = 0.8400833606719971
# **********
# epoch 45
# Finish [50 / 235] batch, accuracy = 0.83203125
# Finish [100 / 235] batch, accuracy = 0.83984375
# Finish [150 / 235] batch, accuracy = 0.82421875
# Finish [200 / 235] batch, accuracy = 0.84375
# Finish [45 / 100], running loss = 112.67281678318977, accuracy = 0.8403499722480774
# **********
# epoch 46
# Finish [50 / 235] batch, accuracy = 0.84375
# Finish [100 / 235] batch, accuracy = 0.84765625
# Finish [150 / 235] batch, accuracy = 0.8203125
# Finish [200 / 235] batch, accuracy = 0.88671875
# Finish [46 / 100], running loss = 112.39665201306343, accuracy = 0.8405500054359436
# **********
# epoch 47
# Finish [50 / 235] batch, accuracy = 0.81640625
# Finish [100 / 235] batch, accuracy = 0.8125
# Finish [150 / 235] batch, accuracy = 0.84375
# Finish [200 / 235] batch, accuracy = 0.81640625
# Finish [47 / 100], running loss = 112.12147763371468, accuracy = 0.8409333229064941
# **********
# epoch 48
# Finish [50 / 235] batch, accuracy = 0.83203125
# Finish [100 / 235] batch, accuracy = 0.8203125
# Finish [150 / 235] batch, accuracy = 0.90234375
# Finish [200 / 235] batch, accuracy = 0.87109375
# Finish [48 / 100], running loss = 111.81923913955688, accuracy = 0.8410833477973938
# **********
# epoch 49
# Finish [50 / 235] batch, accuracy = 0.8203125
# Finish [100 / 235] batch, accuracy = 0.78515625
# Finish [150 / 235] batch, accuracy = 0.890625
# Finish [200 / 235] batch, accuracy = 0.8671875
# Finish [49 / 100], running loss = 111.49561604857445, accuracy = 0.8415166735649109
# **********
# epoch 50
# Finish [50 / 235] batch, accuracy = 0.82421875
# Finish [100 / 235] batch, accuracy = 0.80078125
# Finish [150 / 235] batch, accuracy = 0.8515625
# Finish [200 / 235] batch, accuracy = 0.8359375
# Finish [50 / 100], running loss = 111.30855429172516, accuracy = 0.841783344745636
# **********
# epoch 51
# Finish [50 / 235] batch, accuracy = 0.8671875
# Finish [100 / 235] batch, accuracy = 0.8359375
# Finish [150 / 235] batch, accuracy = 0.8359375
# Finish [200 / 235] batch, accuracy = 0.83203125
# Finish [51 / 100], running loss = 110.92842170596123, accuracy = 0.8420833349227905
# **********
# epoch 52
# Finish [50 / 235] batch, accuracy = 0.890625
# Finish [100 / 235] batch, accuracy = 0.83984375
# Finish [150 / 235] batch, accuracy = 0.828125
# Finish [200 / 235] batch, accuracy = 0.83203125
# Finish [52 / 100], running loss = 110.7271020412445, accuracy = 0.8422166705131531
# **********
# epoch 53
# Finish [50 / 235] batch, accuracy = 0.828125
# Finish [100 / 235] batch, accuracy = 0.875
# Finish [150 / 235] batch, accuracy = 0.87109375
# Finish [200 / 235] batch, accuracy = 0.859375
# Finish [53 / 100], running loss = 110.63295257091522, accuracy = 0.8426666855812073
# **********
# epoch 54
# Finish [50 / 235] batch, accuracy = 0.8359375
# Finish [100 / 235] batch, accuracy = 0.87890625
# Finish [150 / 235] batch, accuracy = 0.86328125
# Finish [200 / 235] batch, accuracy = 0.8203125
# Finish [54 / 100], running loss = 110.1993380188942, accuracy = 0.843583345413208
# **********
# epoch 55
# Finish [50 / 235] batch, accuracy = 0.86328125
# Finish [100 / 235] batch, accuracy = 0.83984375
# Finish [150 / 235] batch, accuracy = 0.875
# Finish [200 / 235] batch, accuracy = 0.8203125
# Finish [55 / 100], running loss = 110.07391646504402, accuracy = 0.8429166674613953
# **********
# epoch 56
# Finish [50 / 235] batch, accuracy = 0.8671875
# Finish [100 / 235] batch, accuracy = 0.79296875
# Finish [150 / 235] batch, accuracy = 0.828125
# Finish [200 / 235] batch, accuracy = 0.83984375
# Finish [56 / 100], running loss = 109.78945282101631, accuracy = 0.8436833620071411
# **********
# epoch 57
# Finish [50 / 235] batch, accuracy = 0.87890625
# Finish [100 / 235] batch, accuracy = 0.86328125
# Finish [150 / 235] batch, accuracy = 0.8515625
# Finish [200 / 235] batch, accuracy = 0.8359375
# Finish [57 / 100], running loss = 109.59992372989655, accuracy = 0.8440499901771545
# **********
# epoch 58
# Finish [50 / 235] batch, accuracy = 0.83984375
# Finish [100 / 235] batch, accuracy = 0.85546875
# Finish [150 / 235] batch, accuracy = 0.85546875
# Finish [200 / 235] batch, accuracy = 0.8671875
# Finish [58 / 100], running loss = 109.33385011553764, accuracy = 0.8447666764259338
# **********
# epoch 59
# Finish [50 / 235] batch, accuracy = 0.88671875
# Finish [100 / 235] batch, accuracy = 0.859375
# Finish [150 / 235] batch, accuracy = 0.83984375
# Finish [200 / 235] batch, accuracy = 0.83984375
# Finish [59 / 100], running loss = 109.16688227653503, accuracy = 0.8449500203132629
# **********
# epoch 60
# Finish [50 / 235] batch, accuracy = 0.84765625
# Finish [100 / 235] batch, accuracy = 0.85546875
# Finish [150 / 235] batch, accuracy = 0.875
# Finish [200 / 235] batch, accuracy = 0.83984375
# Finish [60 / 100], running loss = 109.05064764618874, accuracy = 0.8452666401863098
# **********
# epoch 61
# Finish [50 / 235] batch, accuracy = 0.90234375
# Finish [100 / 235] batch, accuracy = 0.83984375
# Finish [150 / 235] batch, accuracy = 0.875
# Finish [200 / 235] batch, accuracy = 0.87109375
# Finish [61 / 100], running loss = 108.77113017439842, accuracy = 0.8451666831970215
# **********
# epoch 62
# Finish [50 / 235] batch, accuracy = 0.8515625
# Finish [100 / 235] batch, accuracy = 0.80859375
# Finish [150 / 235] batch, accuracy = 0.85546875
# Finish [200 / 235] batch, accuracy = 0.828125
# Finish [62 / 100], running loss = 108.44299528002739, accuracy = 0.8451166749000549
# **********
# epoch 63
# Finish [50 / 235] batch, accuracy = 0.8671875
# Finish [100 / 235] batch, accuracy = 0.7890625
# Finish [150 / 235] batch, accuracy = 0.87890625
# Finish [200 / 235] batch, accuracy = 0.82421875
# Finish [63 / 100], running loss = 108.35295394062996, accuracy = 0.8454333543777466
# **********
# epoch 64
# Finish [50 / 235] batch, accuracy = 0.87109375
# Finish [100 / 235] batch, accuracy = 0.87890625
# Finish [150 / 235] batch, accuracy = 0.86328125
# Finish [200 / 235] batch, accuracy = 0.828125
# Finish [64 / 100], running loss = 108.07669472694397, accuracy = 0.8462666869163513
# **********
# epoch 65
# Finish [50 / 235] batch, accuracy = 0.859375
# Finish [100 / 235] batch, accuracy = 0.87890625
# Finish [150 / 235] batch, accuracy = 0.8125
# Finish [200 / 235] batch, accuracy = 0.84375
# Finish [65 / 100], running loss = 108.08147755265236, accuracy = 0.8458999991416931
# **********
# epoch 66
# Finish [50 / 235] batch, accuracy = 0.87109375
# Finish [100 / 235] batch, accuracy = 0.8515625
# Finish [150 / 235] batch, accuracy = 0.84765625
# Finish [200 / 235] batch, accuracy = 0.83203125
# Finish [66 / 100], running loss = 107.71561855077744, accuracy = 0.8458499908447266
# **********
# epoch 67
# Finish [50 / 235] batch, accuracy = 0.80859375
# Finish [100 / 235] batch, accuracy = 0.82421875
# Finish [150 / 235] batch, accuracy = 0.84375
# Finish [200 / 235] batch, accuracy = 0.875
# Finish [67 / 100], running loss = 107.60753440856934, accuracy = 0.8464000225067139
# **********
# epoch 68
# Finish [50 / 235] batch, accuracy = 0.828125
# Finish [100 / 235] batch, accuracy = 0.8515625
# Finish [150 / 235] batch, accuracy = 0.87109375
# Finish [200 / 235] batch, accuracy = 0.84375
# Finish [68 / 100], running loss = 107.40931332111359, accuracy = 0.8465333580970764
# **********
# epoch 69
# Finish [50 / 235] batch, accuracy = 0.796875
# Finish [100 / 235] batch, accuracy = 0.91015625
# Finish [150 / 235] batch, accuracy = 0.82421875
# Finish [200 / 235] batch, accuracy = 0.84375
# Finish [69 / 100], running loss = 107.18631917238235, accuracy = 0.8467000126838684
# **********
# epoch 70
# Finish [50 / 235] batch, accuracy = 0.859375
# Finish [100 / 235] batch, accuracy = 0.85546875
# Finish [150 / 235] batch, accuracy = 0.86328125
# Finish [200 / 235] batch, accuracy = 0.8515625
# Finish [70 / 100], running loss = 107.06520593166351, accuracy = 0.8468666672706604
# **********
# epoch 71
# Finish [50 / 235] batch, accuracy = 0.86328125
# Finish [100 / 235] batch, accuracy = 0.8359375
# Finish [150 / 235] batch, accuracy = 0.84375
# Finish [200 / 235] batch, accuracy = 0.859375
# Finish [71 / 100], running loss = 106.93478113412857, accuracy = 0.846833348274231
# **********
# epoch 72
# Finish [50 / 235] batch, accuracy = 0.8203125
# Finish [100 / 235] batch, accuracy = 0.81640625
# Finish [150 / 235] batch, accuracy = 0.86328125
# Finish [200 / 235] batch, accuracy = 0.8515625
# Finish [72 / 100], running loss = 106.76685634255409, accuracy = 0.847599983215332
# **********
# epoch 73
# Finish [50 / 235] batch, accuracy = 0.875
# Finish [100 / 235] batch, accuracy = 0.8515625
# Finish [150 / 235] batch, accuracy = 0.84765625
# Finish [200 / 235] batch, accuracy = 0.85546875
# Finish [73 / 100], running loss = 106.6130154132843, accuracy = 0.8472333550453186
# **********
# epoch 74
# Finish [50 / 235] batch, accuracy = 0.875
# Finish [100 / 235] batch, accuracy = 0.84375
# Finish [150 / 235] batch, accuracy = 0.90234375
# Finish [200 / 235] batch, accuracy = 0.8515625
# Finish [74 / 100], running loss = 106.40089735388756, accuracy = 0.8478500247001648
# **********
# epoch 75
# Finish [50 / 235] batch, accuracy = 0.859375
# Finish [100 / 235] batch, accuracy = 0.8515625
# Finish [150 / 235] batch, accuracy = 0.8515625
# Finish [200 / 235] batch, accuracy = 0.82421875
# Finish [75 / 100], running loss = 106.3146116733551, accuracy = 0.8480166792869568
# **********
# epoch 76
# Finish [50 / 235] batch, accuracy = 0.87890625
# Finish [100 / 235] batch, accuracy = 0.84375
# Finish [150 / 235] batch, accuracy = 0.84765625
# Finish [200 / 235] batch, accuracy = 0.859375
# Finish [76 / 100], running loss = 106.15905696153641, accuracy = 0.848550021648407
# **********
# epoch 77
# Finish [50 / 235] batch, accuracy = 0.83203125
# Finish [100 / 235] batch, accuracy = 0.8515625
# Finish [150 / 235] batch, accuracy = 0.8203125
# Finish [200 / 235] batch, accuracy = 0.83984375
# Finish [77 / 100], running loss = 106.04515454173088, accuracy = 0.8487499952316284
# **********
# epoch 78
# Finish [50 / 235] batch, accuracy = 0.86328125
# Finish [100 / 235] batch, accuracy = 0.84375
# Finish [150 / 235] batch, accuracy = 0.8515625
# Finish [200 / 235] batch, accuracy = 0.81640625
# Finish [78 / 100], running loss = 105.84159335494041, accuracy = 0.8485000133514404
# **********
# epoch 79
# Finish [50 / 235] batch, accuracy = 0.82421875
# Finish [100 / 235] batch, accuracy = 0.84375
# Finish [150 / 235] batch, accuracy = 0.84765625
# Finish [200 / 235] batch, accuracy = 0.85546875
# Finish [79 / 100], running loss = 105.66738119721413, accuracy = 0.8485000133514404
# **********
# epoch 80
# Finish [50 / 235] batch, accuracy = 0.86328125
# Finish [100 / 235] batch, accuracy = 0.875
# Finish [150 / 235] batch, accuracy = 0.859375
# Finish [200 / 235] batch, accuracy = 0.86328125
# Finish [80 / 100], running loss = 105.61892768740654, accuracy = 0.8487833142280579
# **********
# epoch 81
# Finish [50 / 235] batch, accuracy = 0.8671875
# Finish [100 / 235] batch, accuracy = 0.8515625
# Finish [150 / 235] batch, accuracy = 0.81640625
# Finish [200 / 235] batch, accuracy = 0.83984375
# Finish [81 / 100], running loss = 105.60735073685646, accuracy = 0.8488333225250244
# **********
# epoch 82
# Finish [50 / 235] batch, accuracy = 0.86328125
# Finish [100 / 235] batch, accuracy = 0.86328125
# Finish [150 / 235] batch, accuracy = 0.86328125
# Finish [200 / 235] batch, accuracy = 0.81640625
# Finish [82 / 100], running loss = 105.26641899347305, accuracy = 0.8492666482925415
# **********
# epoch 83
# Finish [50 / 235] batch, accuracy = 0.88671875
# Finish [100 / 235] batch, accuracy = 0.828125
# Finish [150 / 235] batch, accuracy = 0.8671875
# Finish [200 / 235] batch, accuracy = 0.87109375
# Finish [83 / 100], running loss = 105.2390068769455, accuracy = 0.8495166897773743
# **********
# epoch 84
# Finish [50 / 235] batch, accuracy = 0.8515625
# Finish [100 / 235] batch, accuracy = 0.8515625
# Finish [150 / 235] batch, accuracy = 0.82421875
# Finish [200 / 235] batch, accuracy = 0.86328125
# Finish [84 / 100], running loss = 105.06474938988686, accuracy = 0.849566638469696
# **********
# epoch 85
# Finish [50 / 235] batch, accuracy = 0.859375
# Finish [100 / 235] batch, accuracy = 0.84765625
# Finish [150 / 235] batch, accuracy = 0.83203125
# Finish [200 / 235] batch, accuracy = 0.859375
# Finish [85 / 100], running loss = 105.09633886814117, accuracy = 0.8496500253677368
# **********
# epoch 86
# Finish [50 / 235] batch, accuracy = 0.84375
# Finish [100 / 235] batch, accuracy = 0.828125
# Finish [150 / 235] batch, accuracy = 0.8515625
# Finish [200 / 235] batch, accuracy = 0.84765625
# Finish [86 / 100], running loss = 104.84760317206383, accuracy = 0.8499333262443542
# **********
# epoch 87
# Finish [50 / 235] batch, accuracy = 0.83984375
# Finish [100 / 235] batch, accuracy = 0.828125
# Finish [150 / 235] batch, accuracy = 0.87109375
# Finish [200 / 235] batch, accuracy = 0.84375
# Finish [87 / 100], running loss = 104.68191075325012, accuracy = 0.8496666550636292
# **********
# epoch 88
# Finish [50 / 235] batch, accuracy = 0.8359375
# Finish [100 / 235] batch, accuracy = 0.83984375
# Finish [150 / 235] batch, accuracy = 0.85546875
# Finish [200 / 235] batch, accuracy = 0.83203125
# Finish [88 / 100], running loss = 104.61854913830757, accuracy = 0.8499000072479248
# **********
# epoch 89
# Finish [50 / 235] batch, accuracy = 0.83203125
# Finish [100 / 235] batch, accuracy = 0.84765625
# Finish [150 / 235] batch, accuracy = 0.84765625
# Finish [200 / 235] batch, accuracy = 0.84375
# Finish [89 / 100], running loss = 104.60458767414093, accuracy = 0.8503333330154419
# **********
# epoch 90
# Finish [50 / 235] batch, accuracy = 0.83203125
# Finish [100 / 235] batch, accuracy = 0.87109375
# Finish [150 / 235] batch, accuracy = 0.859375
# Finish [200 / 235] batch, accuracy = 0.89453125
# Finish [90 / 100], running loss = 104.32728427648544, accuracy = 0.8498499989509583
# **********
# epoch 91
# Finish [50 / 235] batch, accuracy = 0.83984375
# Finish [100 / 235] batch, accuracy = 0.859375
# Finish [150 / 235] batch, accuracy = 0.83203125
# Finish [200 / 235] batch, accuracy = 0.8125
# Finish [91 / 100], running loss = 104.27209737896919, accuracy = 0.8503333330154419
# **********
# epoch 92
# Finish [50 / 235] batch, accuracy = 0.85546875
# Finish [100 / 235] batch, accuracy = 0.8203125
# Finish [150 / 235] batch, accuracy = 0.8671875
# Finish [200 / 235] batch, accuracy = 0.859375
# Finish [92 / 100], running loss = 104.08841302990913, accuracy = 0.8506500124931335
# **********
# epoch 93
# Finish [50 / 235] batch, accuracy = 0.859375
# Finish [100 / 235] batch, accuracy = 0.87890625
# Finish [150 / 235] batch, accuracy = 0.875
# Finish [200 / 235] batch, accuracy = 0.796875
# Finish [93 / 100], running loss = 104.1119344830513, accuracy = 0.8505333065986633
# **********
# epoch 94
# Finish [50 / 235] batch, accuracy = 0.83203125
# Finish [100 / 235] batch, accuracy = 0.86328125
# Finish [150 / 235] batch, accuracy = 0.83984375
# Finish [200 / 235] batch, accuracy = 0.85546875
# Finish [94 / 100], running loss = 103.9157242178917, accuracy = 0.8504833579063416
# **********
# epoch 95
# Finish [50 / 235] batch, accuracy = 0.86328125
# Finish [100 / 235] batch, accuracy = 0.8125
# Finish [150 / 235] batch, accuracy = 0.89453125
# Finish [200 / 235] batch, accuracy = 0.875
# Finish [95 / 100], running loss = 103.76711627840996, accuracy = 0.850766658782959
# **********
# epoch 96
# Finish [50 / 235] batch, accuracy = 0.84375
# Finish [100 / 235] batch, accuracy = 0.8359375
# Finish [150 / 235] batch, accuracy = 0.8671875
# Finish [200 / 235] batch, accuracy = 0.8671875
# Finish [96 / 100], running loss = 103.68440142273903, accuracy = 0.8511999845504761
# **********
# epoch 97
# Finish [50 / 235] batch, accuracy = 0.85546875
# Finish [100 / 235] batch, accuracy = 0.859375
# Finish [150 / 235] batch, accuracy = 0.81640625
# Finish [200 / 235] batch, accuracy = 0.83203125
# Finish [97 / 100], running loss = 103.56921970844269, accuracy = 0.8513666391372681
# **********
# epoch 98
# Finish [50 / 235] batch, accuracy = 0.828125
# Finish [100 / 235] batch, accuracy = 0.86328125
# Finish [150 / 235] batch, accuracy = 0.8359375
# Finish [200 / 235] batch, accuracy = 0.7890625
# Finish [98 / 100], running loss = 103.45941644906998, accuracy = 0.8511333465576172
# **********
# epoch 99
# Finish [50 / 235] batch, accuracy = 0.81640625
# Finish [100 / 235] batch, accuracy = 0.83203125
# Finish [150 / 235] batch, accuracy = 0.79296875
# Finish [200 / 235] batch, accuracy = 0.90234375
# Finish [99 / 100], running loss = 103.41697400808334, accuracy = 0.8516833186149597
# **********
# epoch 100
# Finish [50 / 235] batch, accuracy = 0.83984375
# Finish [100 / 235] batch, accuracy = 0.82421875
# Finish [150 / 235] batch, accuracy = 0.85546875
# Finish [200 / 235] batch, accuracy = 0.828125
# Finish [100 / 100], running loss = 103.46601223945618, accuracy = 0.8508833050727844

# %%
i[0].numpy().shape, i[1].numpy().shape
# batch size 64
# Out:
# ((64, 1, 28, 28), (64,))

# %%
i[0].view(64, -1).shape
# Out:
# torch.Size([64, 784])
