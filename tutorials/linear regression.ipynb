# %%
import matplotlib.pyplot as plt
import numpy as np
import sys
import os

import torch
from torch import nn
from torch.autograd import Variable

# %% [markdown]
# ### About File Directory

# %%
import os
os.curdir, os.path.abspath('.'), os.path.abspath(os.curdir)
# Out:
# ('.',
#  'c:\\Users\\tashuangjie\\Desktop\\Code\\torch-tutorial\\tutorials',
#  'c:\\Users\\tashuangjie\\Desktop\\Code\\torch-tutorial\\tutorials')

# %%
os.listdir("..")
# Out:
# ['.git',
#  '.gitignore',
#  'datasets',
#  'md',
#  'README.md',
#  'saved_models',
#  'tutorials',
#  'utils']

# %%
sys.path
sys.path.append('.')
sys.path.append('..')

# %%
sys.path
# Out:
# ['c:\\Users\\tashuangjie\\Desktop\\Code\\torch-tutorial\\tutorials',
#  'c:\\Users\\tashuangjie\\Anaconda3\\envs\\Pytorch_cpu\\python37.zip',
#  'c:\\Users\\tashuangjie\\Anaconda3\\envs\\Pytorch_cpu\\DLLs',
#  'c:\\Users\\tashuangjie\\Anaconda3\\envs\\Pytorch_cpu\\lib',
#  'c:\\Users\\tashuangjie\\Anaconda3\\envs\\Pytorch_cpu',
#  '',
#  'c:\\Users\\tashuangjie\\Anaconda3\\envs\\Pytorch_cpu\\lib\\site-packages',
#  'c:\\Users\\tashuangjie\\Anaconda3\\envs\\Pytorch_cpu\\lib\\site-packages\\win32',
#  'c:\\Users\\tashuangjie\\Anaconda3\\envs\\Pytorch_cpu\\lib\\site-packages\\win32\\lib',
#  'c:\\Users\\tashuangjie\\Anaconda3\\envs\\Pytorch_cpu\\lib\\site-packages\\Pythonwin',
#  'c:\\Users\\tashuangjie\\Anaconda3\\envs\\Pytorch_cpu\\lib\\site-packages\\IPython\\extensions',
#  'C:\\Users\\tashuangjie\\.ipython',
#  '.',
#  '..']

# %%
from utils.download_huggingface_model import download

# %%
x_train = np.array([[3.3], [4.4], [5.5], [6.71], [6.93], [4.168],
                    [9.779], [6.182], [7.59], [2.167], [7.042],
                    [10.791], [5.313], [7.997], [3.1]], dtype=np.float32)
x_train, x_train.shape
# Out:
# (array([[ 3.3  ],
#         [ 4.4  ],
#         [ 5.5  ],
#         [ 6.71 ],
#         [ 6.93 ],
#         [ 4.168],
#         [ 9.779],
#         [ 6.182],
#         [ 7.59 ],
#         [ 2.167],
#         [ 7.042],
#         [10.791],
#         [ 5.313],
#         [ 7.997],
#         [ 3.1  ]], dtype=float32),
#  (15, 1))

# %%
y_train = np.array([[1.7], [2.76], [2.09], [3.19], [1.694], [1.573],
                    [3.366], [2.596], [2.53], [1.221], [2.827],
                    [3.465], [1.65], [2.904], [1.3]], dtype=np.float32)
y_train, y_train.shape
# Out:
# (array([[1.7  ],
#         [2.76 ],
#         [2.09 ],
#         [3.19 ],
#         [1.694],
#         [1.573],
#         [3.366],
#         [2.596],
#         [2.53 ],
#         [1.221],
#         [2.827],
#         [3.465],
#         [1.65 ],
#         [2.904],
#         [1.3  ]], dtype=float32),
#  (15, 1))

# %%
x_train = torch.from_numpy(x_train) # or torch.Tensor(x_train)
x_train
# Out:
# tensor([[ 3.3000],
#         [ 4.4000],
#         [ 5.5000],
#         [ 6.7100],
#         [ 6.9300],
#         [ 4.1680],
#         [ 9.7790],
#         [ 6.1820],
#         [ 7.5900],
#         [ 2.1670],
#         [ 7.0420],
#         [10.7910],
#         [ 5.3130],
#         [ 7.9970],
#         [ 3.1000]])

# %%
y_train = torch.from_numpy(y_train)
y_train
# Out:
# tensor([[1.7000],
#         [2.7600],
#         [2.0900],
#         [3.1900],
#         [1.6940],
#         [1.5730],
#         [3.3660],
#         [2.5960],
#         [2.5300],
#         [1.2210],
#         [2.8270],
#         [3.4650],
#         [1.6500],
#         [2.9040],
#         [1.3000]])

# %%
x_train, x_train.shape, y_train, y_train.shape
# Out:
# (tensor([[ 3.3000],
#          [ 4.4000],
#          [ 5.5000],
#          [ 6.7100],
#          [ 6.9300],
#          [ 4.1680],
#          [ 9.7790],
#          [ 6.1820],
#          [ 7.5900],
#          [ 2.1670],
#          [ 7.0420],
#          [10.7910],
#          [ 5.3130],
#          [ 7.9970],
#          [ 3.1000]]),
#  torch.Size([15, 1]),
#  tensor([[1.7000],
#          [2.7600],
#          [2.0900],
#          [3.1900],
#          [1.6940],
#          [1.5730],
#          [3.3660],
#          [2.5960],
#          [2.5300],
#          [1.2210],
#          [2.8270],
#          [3.4650],
#          [1.6500],
#          [2.9040],
#          [1.3000]]),
#  torch.Size([15, 1]))

# %%
# a quick intro/demo to the usage of super().__init__()
class Rectangle:
    def __init__(self, length, width):
        self.length = length
        self.width = width

    def area(self):
        return self.length * self.width

    def perimeter(self):
        return 2 * self.length + 2 * self.width

# Here we declare that the Square class inherits from the Rectangle class
class Square(Rectangle):
    def __init__(self, length):
        # super().__init__(length, length)
        super(Square, self).__init__(length, length)

a = Rectangle(5, 4)
print(a.area())

b = Square(4)
print(b.area())
# Out:
# 20
# 16

# %%
# Linear Regression Model
class linearRegression(nn.Module):
    def __init__(self):
        super(linearRegression, self).__init__()
        self.linear = nn.Linear(1, 1)  # input and output is 1 dimension

    def forward(self, x):
        out = self.linear(x)
        return out

# %%
if __name__ == "__main__":
    
    # init
    model = linearRegression()
    criterion = nn.MSELoss() # loss function
    optimizer = torch.optim.SGD(model.parameters(), lr=1e-4)
    
    # training
    print("Begin training...")
    num_epochs = 1000
    
    for epoch in range(num_epochs):
        # data
        inputs = x_train
        target = y_train
        
        # forward
        out = model(inputs)
        loss = criterion(out, target)
        
        # backward
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        
        # log the info and result
        if epoch % 20 == 0:
            print(f'Epoch[{epoch}/{num_epochs}], loss: {loss.item():.6f}')
    
    # finish training
    print("training is done...")
    
    # save the model
    torch.save(model.state_dict(), '../saved_models/linearRegression.pth')
    print("Model is saved at /saved_models")
    
    # validation
    model.eval()
    with torch.no_grad():
        y_predict = model(x_train)
        
    # check the validation result  
    fig = plt.figure(figsize=(10, 5))
    plt.plot(x_train.numpy(), y_train.numpy(), 'ro', label='Original data')
    plt.plot(x_train.numpy(), y_predict, label='Fitting Line')
    plt.legend() 
    plt.show()
# Out:
# Begin training...
# Epoch[0/1000], loss: 0.989061
# Epoch[20/1000], loss: 0.797394
# Epoch[40/1000], loss: 0.661885
# Epoch[60/1000], loss: 0.566064
# Epoch[80/1000], loss: 0.498293
# Epoch[100/1000], loss: 0.450346
# Epoch[120/1000], loss: 0.416410
# Epoch[140/1000], loss: 0.392376
# Epoch[160/1000], loss: 0.375340
# Epoch[180/1000], loss: 0.363251
# Epoch[200/1000], loss: 0.354657
# Epoch[220/1000], loss: 0.348533
# Epoch[240/1000], loss: 0.344156
# Epoch[260/1000], loss: 0.341012
# Epoch[280/1000], loss: 0.338741
# Epoch[300/1000], loss: 0.337087
# Epoch[320/1000], loss: 0.335868
# Epoch[340/1000], loss: 0.334957
# Epoch[360/1000], loss: 0.334264
# Epoch[380/1000], loss: 0.333725
# Epoch[400/1000], loss: 0.333295
# Epoch[420/1000], loss: 0.332942
# Epoch[440/1000], loss: 0.332643
# Epoch[460/1000], loss: 0.332383
# Epoch[480/1000], loss: 0.332150
# Epoch[500/1000], loss: 0.331936
# Epoch[520/1000], loss: 0.331736
# Epoch[540/1000], loss: 0.331546
# Epoch[560/1000], loss: 0.331363
# ...

# %% [markdown]
# ## Modify: Non-linear regression and see overfit!

# %%
# No-Linear Regression Model
class NonlinearRegression(nn.Module):
    def __init__(self):
        super(NonlinearRegression, self).__init__()
        self.net = nn.Sequential(
            nn.Linear(1, 20),
            nn.ReLU(),
            nn.Linear(20, 20),
            nn.ReLU(),
            nn.Linear(20, 20),
            nn.ReLU(),
            nn.Linear(20, 20),
            nn.ReLU(),
            nn.Linear(20, 20),
            nn.ReLU(),                   
            nn.Linear(20, 1)
        )
    def forward(self, x):
        out = self.net(x)
        return out


if __name__ == "__main__":
    
    # init
    model = NonlinearRegression()
    criterion = nn.MSELoss() # loss function
    optimizer = torch.optim.SGD(model.parameters(), lr=3e-2)
    
    # training
    print("Begin training...")
    num_epochs = 100000
    
    for epoch in range(num_epochs):
        # data
        inputs = x_train
        target = y_train
        
        # forward
        out = model(inputs)
        loss = criterion(out, target)
        
        # backward
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        
        # log the info and result
        if epoch % 20 == 0:
            print(f'Epoch[{epoch}/{num_epochs}], loss: {loss.item():.6f}')
    
    # finish training
    print("training is done...")
    
    # save the model
    torch.save(model.state_dict(), '../saved_models/NonlinearRegression.pth')
    print("Model is saved at /saved_models")
    
    # validation
    model.eval()
    with torch.no_grad():
        y_predict = model(x_train)
        
    # check the validation result  
    fig = plt.figure(figsize=(10, 5))
    plt.plot(x_train.numpy(), y_train.numpy(), 'ro', label='Original data')
    plt.plot(x_train.numpy(), y_predict, 'bo', label='Fitting Line')
    plt.legend() 
    plt.show()
# Out:
# Begin training...
# Epoch[0/100000], loss: 6.077420
# Epoch[20/100000], loss: 0.282745
# Epoch[40/100000], loss: 0.250612
# Epoch[60/100000], loss: 0.216938
# Epoch[80/100000], loss: 0.205247
# Epoch[100/100000], loss: 0.200780
# Epoch[120/100000], loss: 0.198705
# Epoch[140/100000], loss: 0.197116
# Epoch[160/100000], loss: 0.195480
# Epoch[180/100000], loss: 0.193965
# Epoch[200/100000], loss: 0.192537
# Epoch[220/100000], loss: 0.191211
# Epoch[240/100000], loss: 0.189992
# Epoch[260/100000], loss: 0.188806
# Epoch[280/100000], loss: 0.187708
# Epoch[300/100000], loss: 0.186589
# Epoch[320/100000], loss: 0.185678
# Epoch[340/100000], loss: 0.184723
# Epoch[360/100000], loss: 0.183827
# Epoch[380/100000], loss: 0.182984
# Epoch[400/100000], loss: 0.182295
# Epoch[420/100000], loss: 0.181567
# Epoch[440/100000], loss: 0.180700
# Epoch[460/100000], loss: 0.179664
# Epoch[480/100000], loss: 0.179111
# Epoch[500/100000], loss: 0.178323
# Epoch[520/100000], loss: 0.177344
# ...

# %%
t = np.arange(2, 13, 0.01, dtype=np.float32)
t = t.reshape(-1, 1)
new_x = torch.Tensor(t)

# validation
model.eval()
with torch.no_grad():
    y_predict = model(new_x)
    
# check the validation result  
fig = plt.figure(figsize=(10, 5))
plt.plot(x_train.numpy(), y_train.numpy(), 'ro', label='Original data')
plt.plot(new_x, y_predict, 'bo', label='Fitting Line')
plt.legend() 
plt.show()
